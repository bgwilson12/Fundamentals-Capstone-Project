# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_html('http://www.nationsonline.org/oneworld/currencies.htm')[2:7]
df[0]
for each in df:
    each.drop([0, 4, 5], axis=1, inplace=True)
    each.columns = each.iloc[0]
df = pd.concat(df)
df.head()
# Out:
# 0                                            Country   Currency Name  Code A
# 0                                            Country   Currency Name  Code A
# 1  1 Japanese Yen 2 Ethiopian Birr  1. U.S. Dolla...             NaN     NaN
# 2                                        Afghanistan         Afghani     AFN
# 3                                            Albania             Lek     ALL
# 4                                            Algeria  Algerian Dinar     DZD

# %%
df2 = pd.read_html('http://www.nationsonline.org/oneworld/countries-classification.htm')[2]
df2.drop([0, 1, 4, 5, 6], axis=1, inplace=True)
df2.columns = df2.iloc[0,:]
for i, country in enumerate(df2['Country']):
    df2.loc[i, 'Country'] = country.replace('*', '')
df2.drop(0, inplace=True)
df2
# Out:
# 0                   Country Ctry Code
# 1               Afghanistan       AFG
# 2                   Albania       ALB
# 3                   Algeria       DZA
# 4                   Andorra       AND
# 5                    Angola       AGO
# 6       Antigua and Barbuda       ATG
# 7                 Argentina       ARG
# 8                   Armenia       ARM
# 9                 Australia       AUS
# 10                  Austria       AUT
# 11               Azerbaijan       AZE
# 12                  Bahamas       BHS
# 13                  Bahrain       BHR
# 14               Bangladesh       BGD
# 15                 Barbados       BRB
# 16                  Belarus       BLR
# 17                  Belgium       BEL
# 18                   Belize       BLZ
# 19                    Benin       BEN
# 20                  Bermuda       BMU
# 21                   Bhutan       BTN
# 22                  Bolivia       BOL
# 23   Bosnia and Herzegovina       BIH
# 24                 Botswana       BWA
# ...
